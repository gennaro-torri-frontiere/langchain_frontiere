# %%
import sys
sys.path.append("..")

# %%
from rag_components.embeddings import list_embeddings

# %%
def ciao():
    print("ciao")

# %%
list_embeddings()
# Out:
# ['list_embeddings', 'bge_small']

# %%
import langchain_community.document_loaders.pdf
